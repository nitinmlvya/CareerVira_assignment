# %% [markdown]
# ## Based on the user’s ratings which factors are important among taste, aroma, appearance, and palette?

# %%
import pandas as pd

# %%
df = pd.read_csv('data/BeerDataScienceProject.csv', engine='python')
df.shape

df.head()
# Out:
#    beer_ABV  beer_beerId  beer_brewerId               beer_name  \
# 0       5.0        47986          10325            Sausa Weizen
# 1       6.2        48213          10325                Red Moon
# 2       6.5        48215          10325  Black Horse Black Beer
# 3       5.0        47969          10325              Sausa Pils
# 4       7.7        64883           1075           Cauldron DIPA
#
#                        beer_style  review_appearance  review_palette  \
# 0                      Hefeweizen                2.5             2.0
# 1              English Strong Ale                3.0             2.5
# 2          Foreign / Export Stout                3.0             2.5
# 3                 German Pilsener                3.5             3.0
# 4  American Double / Imperial IPA                4.0             4.5
#
#    review_overall  review_taste review_profileName  review_aroma  \
# 0             1.5           1.5            stcules           1.5
# ...

# %%
df_review = df[['review_overall', 'review_appearance', 'review_palette', 'review_taste', 'review_aroma']] 
df_review.head(2)
# Out:
#    review_overall  review_appearance  review_palette  review_taste  \
# 0             1.5                2.5             2.0           1.5
# 1             3.0                3.0             2.5           3.0
#
#    review_aroma
# 0           1.5
# 1           3.0

# %%
df_review.corr()
# Out:
#                    review_overall  review_appearance  review_palette  \
# review_overall           1.000000           0.486687        0.601971
# review_appearance        0.486687           1.000000        0.547691
# review_palette           0.601971           0.547691        1.000000
# review_taste             0.692454           0.554775        0.604271
# review_aroma             0.783002           0.534244        0.706156
#
#                    review_taste  review_aroma
# review_overall         0.692454      0.783002
# review_appearance      0.554775      0.534244
# review_palette         0.604271      0.706156
# review_taste           1.000000      0.725273
# review_aroma           0.725273      1.000000

# %% [markdown]
# ### Aroma is the most important factor.
